# %% [markdown]
# # Run Batch Segmentation

# %%
# !python -m src.segmentation_pipeline --config "processing_config.json"

# %%
#!python -m src.map_transcripts_to_cells --config "config/processing_config_05.json"
#!python -m src.map_transcripts_to_cells --config "config/processing_config_1.json"
#!python -m src.map_transcripts_to_cells --config "config/processing_config_25.json"
#!python -m src.map_transcripts_to_cells --config "config/processing_config_5.json"

# !python -m src.map_transcripts_to_cells --config "config/processing_config_comparison3.json"

# %%
#!python -m src.visualize_gene_expression --proc_config "config/processing_config_05.json" --viz_config "config/visualization_config.json" --task_id "5A_viz"
#!python -m src.visualize_gene_expression --proc_config "config/processing_config_1.json"  --viz_config "config/visualization_config.json" --task_id "5A_viz"
#!python -m src.visualize_gene_expression --proc_config "config/processing_config_25.json" --viz_config "config/visualization_config.json" --task_id "5A_viz"
#!python -m src.visualize_gene_expression --proc_config "config/processing_config_5.json"  --viz_config "config/visualization_config.json" --task_id "5A_viz"

# !python -m src.visualize_gene_expression --proc_config "config/processing_config_comparison4.json"  --viz_config "config/visualization_config_comparison_4.json" --task_id "viz_5C_comparison_nuclei"

# %%
# !python -m src.create_mapping_summary --task_id "5C_viz" --viz_config "config/visualization_config_1.json"  --proc_config "config/processing_config_1.json"
# !python -m src.create_mapping_summary --task_id "5C_viz" --viz_config "config/visualization_config_05.json" --proc_config "config/processing_config_05.json"
# !python -m src.create_mapping_summary --task_id "5C_viz" --viz_config "config/visualization_config_25.json" --proc_config "config/processing_config_25.json"
# !python -m src.create_mapping_summary --task_id "5C_viz" --viz_config "config/visualization_config_5.json"  --proc_config "config/processing_config_5.json"

# %% [markdown]
# # Step 3: Run Transcript Mapping (if configured in mapping_tasks)

# %% [markdown]
# # Step 4: Run Gene Expression Visualization

# %%
# python -m src.visualize_gene_expression --proc_config processing_config.json --viz_config visualization_config.json

python_file_to_run = "src.visualize_gene_expression"

proc_json = "processing_config.json"
viz_json = "visualization_config.json"

# !python -m {python_file_to_run} --proc_config {proc_json} --viz_config {viz_json}
# Out:
# Welcome to CellposeSAM, cellpose v
# cellpose version: 	4.0.3
# platform:       	win32
# python version: 	3.13.0
# torch version:  	2.7.0+cpu! The neural network component of
# CPSAM is much larger than in previous versions and CPU excution is slow.
# We encourage users to use GPU/MPS if available.
# Traceback (most recent call last):
#   File "e:\OneDrive - University of Cambridge\Min-Yao_Thiago_shared_folder\PYcellsegmentation\.venv-cellpose-diag\Lib\site-packages\scipy\__init__.py", line 114, in <module>
#     from scipy._lib._ccallback import LowLevelCallable
#   File "e:\OneDrive - University of Cambridge\Min-Yao_Thiago_shared_folder\PYcellsegmentation\.venv-cellpose-diag\Lib\site-packages\scipy\_lib\_ccallback.py", line 1, in <module>
#     from . import _ccallback_c
# ...
